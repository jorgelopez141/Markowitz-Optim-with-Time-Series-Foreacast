# %% [markdown]
# # WMT Prophet

# %% [markdown]
# ## Init
# - Bringing WMT's stock history
# - Backfilling and only getting business days
# - Creating MAPE fn
# - Adding features to data

# %%
from WMT import stock_hist,stock_hist_daily # stock hist is the monthly one
import pandas as pd 
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
stock = 'WMT'
# Out:
# The current working directory is: d:\MyDrive\10. MS in Data Science UofWisconsin\14. Final Project Maestria\Predicting Stocks\Month to Month
# [*********************100%***********************]  30 of 30 completed

# %%
# MAPE
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# Adding features to data: day, month, year, week nbr, etc...

# %%
### DAILY STOCKS
from function_filePrep import _add_dayMonthYear 

# add month, year, day of week, day of year...
stock_hist_daily1=_add_dayMonthYear(stock_hist_daily)

# %% [markdown]
# ## Basic Prophet Model

# %% [markdown]
# - Add COVID lockdowns as holidays (hexogenous vars)
# - Adds features as additive hexogenous vars

# %%
stock_hist_daily2=stock_hist_daily1.reset_index().rename(columns={'Date':'ds',stock:'y'}).copy()
date_train_test = '2024-06-30'
stock_train2=stock_hist_daily2.loc[stock_hist_daily2.ds<=date_train_test].copy()
stock_test2=stock_hist_daily2.loc[stock_hist_daily2.ds>date_train_test].copy()

## COVID
# Python
lockdowns = pd.DataFrame([
    {'holiday': 'lockdown_1', 'ds': '2020-03-21', 'lower_window': 0, 'ds_upper': '2020-06-06'},
    {'holiday': 'lockdown_2', 'ds': '2020-07-09', 'lower_window': 0, 'ds_upper': '2020-10-27'},
    {'holiday': 'lockdown_3', 'ds': '2021-02-13', 'lower_window': 0, 'ds_upper': '2021-02-17'},
    {'holiday': 'lockdown_4', 'ds': '2021-05-28', 'lower_window': 0, 'ds_upper': '2021-06-10'}
])
for t_col in ['ds', 'ds_upper']:
    lockdowns[t_col] = pd.to_datetime(lockdowns[t_col])
lockdowns['upper_window'] = (lockdowns['ds_upper'] - lockdowns['ds']).dt.days

## END COVID 
#changepoint range dice que encuentra cambios en trend hasta el 90% inicial de la data.
#m = Prophet(holidays=lockdowns, changepoint_range=0.9, changepoint_prior_scale=0.2) 
m = Prophet(holidays=lockdowns) 
# changepoint prior scale es que tan flexible es. valores entre 0.05 y 0.5
m.add_regressor('day')
m.add_regressor('day_of_week')
m.add_regressor('day_of_year')
m.add_regressor('week_of_year')
m.add_regressor('month')
m.add_regressor('quarter')
m.add_regressor('year')
m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
m.fit(stock_train2)


forecast = m.predict(stock_test2)
# Out:
# 12:07:08 - cmdstanpy - INFO - Chain [1] start processing
# 12:07:11 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# **Visualizing ChangePoints and Forecast:** <br>
# - Notice that there is no change in trend spotted in 2024

# %%
from prophet.plot import add_changepoints_to_plot
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)

# %% [markdown]
# Zooming into forecast vs real

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.scatter(stock_test2.ds, stock_test2['y'], color='r', label= 'Actual Test Values')
fig = m.plot(forecast, ax=ax)
ax.set_xbound(lower=pd.to_datetime('2024-07-01'),
              upper=pd.to_datetime('2024-09-30'))
# ax.set_ylim(55, 90)
plt.xticks(rotation=45)
ax.legend(loc='lower left') 
plot = plt.suptitle('Actual vs Forecasted')

# %%
# EVALUATE WITH ERROR METRICS 
mse=np.sqrt(mean_squared_error(y_true=stock_test2['y'],y_pred=forecast['yhat']))

mae = mean_absolute_error(y_true=stock_test2['y'],
                   y_pred=forecast['yhat'])

mape = mean_absolute_percentage_error(y_true=stock_test2['y'],
                   y_pred=forecast['yhat'])

print(mse,mae, mape)
# Out:
# 10.322586904611098 9.588198045842988 12.828875724922973

# %% [markdown]
# Visualizing Trend, Seasonal, and Holiday Components. As well as additional variables.

# %%
# PRINTING COMPONENTS OF MODEL
m.plot_components(forecast)
plt.show()

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# ### Test Horizon for Forecast

# %%
# Python
from prophet.diagnostics import cross_validation
cutoffs = pd.to_datetime(['2024-02-29','2023-12-31','2023-10-31'])
df_cv2 = cross_validation(m, cutoffs=cutoffs, horizon='90 days')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]12:10:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:10:54 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  3.00s/it]12:10:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:10:57 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.63s/it]12:10:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:10:59 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.50s/it]

# %%
# Python
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv2)
df_p.loc[df_p.horizon.isin(['30 days','60 days','90 days'])]
# Out:
#    horizon        mse      rmse       mae      mape     mdape     smape  \
# 21 30 days   8.153624  2.855455  2.396070  0.042954  0.051714  0.043217
# 51 60 days   9.832749  3.135721  2.713415  0.047391  0.031788  0.048597
# 81 90 days  31.872343  5.645560  4.718320  0.075167  0.093002  0.079352
#
#     coverage
# 21  0.350877
# 51  0.526316
# 81  0.315789

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv2, metric='mape')
plt.title('MAPE at Different Horizons')
plt.show()

# %% [markdown]
# **MAPE basically shoots up starting at 60 day horizon.** <br>
# Reason why I decided to stay within 60 day Horizon ↑

# %% [markdown]
# ### CV for Hyperparameter Tuning

# %% [markdown]
# #### From Prophet's Documentation
# https://facebook.github.io/prophet/docs/diagnostics.html#cross-validation
#
# ##### What parameters to Optimize?
#
# - <u>changepoint_prior_scale:</u> This is probably the most impactful parameter. It determines the flexibility of the trend, and in particular how much the trend changes at the trend changepoints. As described in this documentation, if it is too small, the trend will be underfit and variance that should have been modeled with trend changes will instead end up being handled with the noise term. If it is too large, the trend will overfit and in the most extreme case you can end up with the trend capturing yearly seasonality. The default of 0.05 works for many time series, but this could be tuned; a range of [0.001, 0.5] would likely be about right. Parameters like this (regularization penalties; this is effectively a lasso penalty) are often tuned on a log scale.
#
# - <u>seasonality_prior_scale:</u> This parameter controls the flexibility of the seasonality. Similarly, a large value allows the seasonality to fit large fluctuations, a small value shrinks the magnitude of the seasonality. The default is 10., which applies basically no regularization. That is because we very rarely see overfitting here (there’s inherent regularization with the fact that it is being modeled with a truncated Fourier series, so it’s essentially low-pass filtered). A reasonable range for tuning it would probably be [0.01, 10]; when set to 0.01 you should find that the magnitude of seasonality is forced to be very small. This likely also makes sense on a log scale, since it is effectively an L2 penalty like in ridge regression.
#
# - <u>holidays_prior_scale:</u> This controls flexibility to fit holiday effects. Similar to seasonality_prior_scale, it defaults to 10.0 which applies basically no regularization, since we usually have multiple observations of holidays and can do a good job of estimating their effects. This could also be tuned on a range of [0.01, 10] as with seasonality_prior_scale.
#
# - <u>seasonality_mode:</u> Options are ['additive', 'multiplicative']. Default is 'additive', but many business time series will have multiplicative seasonality. This is best identified just from looking at the time series and seeing if the magnitude of seasonal fluctuations grows with the magnitude of the time series (see the documentation here on multiplicative seasonality), but when that isn’t possible, it could be tuned.
#
# - <u>changepoint_range:</u> This is the proportion of the history in which the trend is allowed to change. This defaults to 0.8, 80% of the history, meaning the model will not fit any trend changes in the last 20% of the time series. This is fairly conservative, to avoid overfitting to trend changes at the very end of the time series where there isn’t enough runway left to fit it well. With a human in the loop, this is something that can be identified pretty easily visually: one can pretty clearly see if the forecast is doing a bad job in the last 20%. In a fully-automated setting, it may be beneficial to be less conservative. It likely will not be possible to tune this parameter effectively with cross validation over cutoffs as described above. The ability of the model to generalize from a trend change in the last 10% of the time series will be hard to learn from looking at earlier cutoffs that may not have trend changes in the last 10%. So, this parameter is probably better not tuned, except perhaps over a large number of time series. In that setting, [0.8, 0.95] may be a reasonable range.

# %%
import itertools
stock_hist_daily2=stock_hist_daily1.reset_index().rename(columns={'Date':'ds',stock:'y'}).copy()
date_train_test = '2024-08-31'
stock_train2=stock_hist_daily2.loc[stock_hist_daily2.ds<=date_train_test].copy()
stock_test2=stock_hist_daily2.loc[stock_hist_daily2.ds>date_train_test].copy()

## COVID
# Python
lockdowns = pd.DataFrame([
    {'holiday': 'lockdown_1', 'ds': '2020-03-21', 'lower_window': 0, 'ds_upper': '2020-06-06'},
    {'holiday': 'lockdown_2', 'ds': '2020-07-09', 'lower_window': 0, 'ds_upper': '2020-10-27'},
    {'holiday': 'lockdown_3', 'ds': '2021-02-13', 'lower_window': 0, 'ds_upper': '2021-02-17'},
    {'holiday': 'lockdown_4', 'ds': '2021-05-28', 'lower_window': 0, 'ds_upper': '2021-06-10'}
])
for t_col in ['ds', 'ds_upper']:
    lockdowns[t_col] = pd.to_datetime(lockdowns[t_col])
lockdowns['upper_window'] = (lockdowns['ds_upper'] - lockdowns['ds']).dt.days

param_grid = {  
    'changepoint_prior_scale': [0.01, 0.05, 0.1,0.2,0.5],
    'seasonality_prior_scale': [0.01, 0.05, 0.1, 0.5, 1, 5],
    'changepoint_range': [0.8,0.9,0.95],
    'seasonality_mode': ['additive','multiplicative']    
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

## END COVID 
cutoffs = pd.to_datetime(['2024-02-29','2023-12-31','2023-10-31'])


def fit_and_evaluate(params):
    m = Prophet(**params, holidays=lockdowns)
    m.add_regressor('day')
    m.add_regressor('day_of_week')
    m.add_regressor('day_of_year')
    m.add_regressor('week_of_year')
    m.add_regressor('month')
    m.add_regressor('quarter')
    m.add_regressor('year')
    m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
    m.fit(stock_train2)
    df_cv = cross_validation(m, cutoffs=cutoffs, horizon='60 days')
    df_p = performance_metrics(df_cv, rolling_window=1, metrics=['rmse', 'mape'])
    return df_p['rmse'].values[0]

# Store the RMSEs for each params here
rmses = [fit_and_evaluate(params) for params in all_params]

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
tuning_results.sort_values('rmse')
# Out:
# 12:21:25 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:27 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:21:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:28 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.04s/it]12:21:28 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:29 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.10s/it]12:21:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:30 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# 12:21:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:31 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:21:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:32 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.19s/it]12:21:33 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:33 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.09s/it]12:21:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:34 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.03s/it]
# 12:21:35 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:36 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:21:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:37 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.11s/it]12:21:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:38 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.06s/it]12:21:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:39 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# 12:21:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:40 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:21:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:41 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.22s/it]12:21:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:43 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.31s/it]12:21:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.24s/it]
# 12:21:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:45 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:21:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:47 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.36s/it]12:21:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:48 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.44s/it]12:21:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:49 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.33s/it]
# 12:21:50 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:21:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:52 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.21s/it]12:21:53 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:53 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.13s/it]12:21:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:55 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# 12:21:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:21:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:57 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.16s/it]12:21:58 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:58 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.07s/it]12:21:59 - cmdstanpy - INFO - Chain [1] start processing
# 12:21:59 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.08s/it]
# 12:22:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:00 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:01 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:02 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.39s/it]12:22:02 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:03 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.11s/it]12:22:03 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:04 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
# 12:22:04 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:05 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:06 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:06 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.02s/it]12:22:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:07 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:01<00:00,  1.01it/s]12:22:08 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:08 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# 12:22:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:10 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:11 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.18s/it]12:22:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:12 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.03s/it]12:22:13 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:13 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.14s/it]
# 12:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:16 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:16 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.08s/it]12:22:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:17 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.11s/it]12:22:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:18 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.07s/it]
# 12:22:19 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:20 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:21 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.15s/it]12:22:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:22 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.13s/it]12:22:23 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:23 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.16s/it]
# 12:22:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:25 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:25 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:26 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.07s/it]12:22:26 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:27 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.14s/it]12:22:28 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:28 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# 12:22:29 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:29 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:31 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.37s/it]12:22:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:32 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.33s/it]12:22:33 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:34 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:04<00:00,  1.38s/it]
# 12:22:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:35 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:37 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:03,  1.71s/it]12:22:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:38 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.27s/it]12:22:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:38 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.21s/it]
# 12:22:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:40 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:41 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.17s/it]12:22:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:42 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.30s/it]12:22:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.33s/it]
# 12:22:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:45 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:47 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.17s/it]12:22:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:48 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.28s/it]12:22:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:49 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.27s/it]
# 12:22:50 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:52 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.42s/it]12:22:53 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:53 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.30s/it]12:22:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:55 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.26s/it]
# 12:22:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:22:56 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:57 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.10s/it]12:22:58 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:58 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.04s/it]12:22:58 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:59 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.03s/it]
# 12:23:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:01 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:02 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:03 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.44s/it]12:23:04 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:05 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.01s/it]12:23:06 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:07 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:05<00:00,  1.89s/it]
# 12:23:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:08 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:10 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:03,  1.52s/it]12:23:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:11 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.26s/it]12:23:11 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:12 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.22s/it]
# 12:23:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:15 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:17 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.75s/it]12:23:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:19 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.26s/it]12:23:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:21 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.15s/it]
# 12:23:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:23 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:24 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.08s/it]12:23:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:25 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.12s/it]12:23:26 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:26 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.13s/it]
# 12:23:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:29 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:32 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.69s/it]12:23:33 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:34 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.05s/it]12:23:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:37 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.57s/it]
# 12:23:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:38 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:39 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.00s/it]12:23:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:40 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:01<00:00,  1.04it/s]12:23:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:02<00:00,  1.02it/s]
# 12:23:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:44 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:47 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.46s/it]12:23:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:49 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.79s/it]12:23:50 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:51 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.57s/it]
# 12:23:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:53 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:23:53 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:54 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.25s/it]12:23:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:55 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.08s/it]12:23:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:23:56 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.07s/it]
# 12:23:56 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:00 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:02 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.41s/it]12:24:03 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:06 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:06<00:03,  3.43s/it]12:24:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:09 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:09<00:00,  3.02s/it]
# 12:24:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:10 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:24:11 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:11 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.19s/it]12:24:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:12 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.16s/it]12:24:13 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:13 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.11s/it]
# 12:24:14 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:24:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:19 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.61s/it]12:24:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:22 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:03,  3.00s/it]12:24:23 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:27 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.67s/it]
# 12:24:28 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:29 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:24:29 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:30 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.20s/it]12:24:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:31 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.13s/it]12:24:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:32 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# 12:24:33 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:34 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:24:35 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:37 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.59s/it]12:24:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:41 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:06<00:03,  3.36s/it]12:24:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:08<00:00,  2.78s/it]
# 12:24:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:44 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:24:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:45 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.15s/it]12:24:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:46 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.03s/it]12:24:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:47 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.06s/it]
# 12:24:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:24:51 - cmdstanpy - INFO - Chain [1] start processing
# 12:24:56 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:10,  5.00s/it]12:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:00 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.31s/it]12:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:03 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.90s/it]
# 12:25:03 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:04 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:25:04 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:05 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:01<00:02,  1.12s/it]12:25:06 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:06 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:02<00:01,  1.18s/it]12:25:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:07 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:03<00:00,  1.09s/it]
# 12:25:08 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:12 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:25:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:15 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.35s/it]12:25:16 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:19 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.60s/it]12:25:19 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:23 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.93s/it]
# 12:25:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:26 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:25:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:29 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.36s/it]12:25:29 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:31 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.21s/it]12:25:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:33 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.08s/it]
# 12:25:33 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:35 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:25:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:38 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.41s/it]12:25:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:40 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.36s/it]12:25:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.12s/it]
# 12:25:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:45 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:25:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:48 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.03s/it]12:25:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:51 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.84s/it]12:25:51 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:53 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:08<00:00,  2.67s/it]
# 12:25:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:25:56 - cmdstanpy - INFO - Chain [1] start processing
# 12:25:59 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.23s/it]12:26:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:01 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.72s/it]12:26:02 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:04 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:08<00:00,  2.67s/it]
# 12:26:04 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:06 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:26:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:09 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.84s/it]12:26:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:11 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.40s/it]12:26:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:14 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.64s/it]
# 12:26:15 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:17 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:26:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:19 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.17s/it]12:26:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:20 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:03<00:01,  1.70s/it]12:26:21 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:23 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.12s/it]
# 12:26:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:26 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:26:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:29 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.25s/it]12:26:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:32 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.86s/it]12:26:33 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:34 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# 12:26:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:37 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:26:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:39 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.20s/it]12:26:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:41 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.34s/it]12:26:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:43 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.16s/it]
# 12:26:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:46 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:26:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:49 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.84s/it]12:26:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:51 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.70s/it]12:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:54 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.62s/it]
# 12:26:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:26:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:26:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:00 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.09s/it]12:27:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:02 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.64s/it]12:27:03 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:04 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.58s/it]
# 12:27:05 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:07 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:27:08 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:10 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.46s/it]12:27:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:12 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.36s/it]12:27:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:14 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.46s/it]
# 12:27:15 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:17 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:27:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:19 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.16s/it]12:27:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:21 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.09s/it]12:27:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:24 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.25s/it]
# 12:27:25 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:27 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:27:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:29 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.40s/it]12:27:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:32 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.48s/it]12:27:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:34 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.30s/it]
# 12:27:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:37 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:27:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:40 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.97s/it]12:27:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:43 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:06<00:03,  3.03s/it]12:27:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# 12:27:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:47 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:27:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:50 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.60s/it]12:27:51 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:53 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.62s/it]12:27:53 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:56 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:08<00:00,  2.76s/it]
# 12:27:56 - cmdstanpy - INFO - Chain [1] start processing
# 12:27:58 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:27:59 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:01 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.24s/it]12:28:02 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:04 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.69s/it]12:28:04 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:08 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:09<00:00,  3.18s/it]
# 12:28:08 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:11 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:28:11 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:13 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.58s/it]12:28:14 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:16 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.32s/it]12:28:16 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:18 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.30s/it]
# 12:28:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:20 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:28:21 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:23 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.80s/it]12:28:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:25 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.19s/it]12:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:28 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.44s/it]
# 12:28:28 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:30 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:28:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:33 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.90s/it]12:28:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:35 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.58s/it]12:28:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:37 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.40s/it]
# 12:28:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:41 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:28:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.48s/it]12:28:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:48 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.51s/it]12:28:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:51 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:09<00:00,  3.30s/it]
# 12:28:51 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:53 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:28:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:56 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.13s/it]12:28:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:28:59 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:06<00:03,  3.17s/it]12:29:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:02 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:08<00:00,  2.91s/it]
# 12:29:02 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:06 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:29:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:11 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:10,  5.39s/it]12:29:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:16 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:10<00:04,  4.97s/it]12:29:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:20 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:13<00:00,  4.51s/it]
# 12:29:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:29:23 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:25 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.50s/it]12:29:26 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:27 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.08s/it]12:29:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:30 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.39s/it]
# 12:29:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:34 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:29:35 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:39 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:08,  4.43s/it]12:29:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:42 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.69s/it]12:29:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:46 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.85s/it]
# 12:29:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:48 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:29:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:51 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.58s/it]12:29:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:53 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.40s/it]12:29:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:29:55 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.26s/it]
# 12:29:56 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:00 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:30:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:05 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:10,  5.23s/it]12:30:06 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:10 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:10<00:04,  4.98s/it]12:30:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:15 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:14<00:00,  4.95s/it]
# 12:30:15 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:17 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:30:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:20 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.84s/it]12:30:21 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:24 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:06<00:03,  3.24s/it]12:30:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:25 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:08<00:00,  2.71s/it]
# 12:30:26 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:31 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:30:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:35 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:07,  3.93s/it]12:30:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:41 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:09<00:04,  4.90s/it]12:30:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:46 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:14<00:00,  4.90s/it]
# 12:30:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:48 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:30:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:51 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.46s/it]12:30:51 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:53 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.18s/it]12:30:53 - cmdstanpy - INFO - Chain [1] start processing
# 12:30:55 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:06<00:00,  2.22s/it]
# 12:30:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:00 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:31:01 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:04 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:07,  3.94s/it]12:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:09 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.33s/it]12:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:13 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:12<00:00,  4.32s/it]
# 12:31:14 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:31:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:19 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.92s/it]12:31:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:21 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.53s/it]12:31:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:23 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.39s/it]
# 12:31:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:29 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:31:29 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:34 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:11,  5.56s/it]12:31:35 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:40 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:11<00:05,  5.52s/it]12:31:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:45 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:15<00:00,  5.32s/it]
# 12:31:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:48 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:31:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:51 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.38s/it]12:31:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:54 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:05<00:02,  2.85s/it]12:31:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:31:56 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:08<00:00,  2.90s/it]
# 12:31:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:03 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:32:04 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:09 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:11,  5.77s/it]12:32:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:14 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:11<00:05,  5.79s/it]12:32:15 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:20 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:17<00:00,  5.68s/it]
# 12:32:21 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:32:23 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:25 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:04,  2.45s/it]12:32:26 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:28 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:04<00:02,  2.38s/it]12:32:28 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:31 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:07<00:00,  2.59s/it]
# 12:32:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:35 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:32:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:41 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:11,  5.78s/it]12:32:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:47 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:11<00:05,  5.89s/it]12:32:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:53 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:17<00:00,  5.83s/it]
# 12:32:53 - cmdstanpy - INFO - Chain [1] start processing
# 12:32:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:32:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:01 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:08,  4.31s/it]12:33:01 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:04 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.72s/it]12:33:05 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:07 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:10<00:00,  3.47s/it]
# 12:33:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:11 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:33:11 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:13 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:02<00:05,  2.83s/it]12:33:14 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:17 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:06<00:03,  3.05s/it]12:33:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:20 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:09<00:00,  3.21s/it]
# 12:33:21 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:33:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:28 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:07,  3.81s/it]12:33:28 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:32 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.06s/it]12:33:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:36 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:12<00:00,  4.21s/it]
# 12:33:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:40 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:33:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:44 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:07,  3.98s/it]12:33:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:48 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.64s/it]12:33:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:52 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.80s/it]
# 12:33:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:33:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 12:34:00 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.03s/it]12:34:01 - cmdstanpy - INFO - Chain [1] start processing
# 12:34:03 - cmdstanpy - INFO - Chain [1] done processing
# ...
# 12:55:59 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.46s/it]12:56:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:04 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:13<00:00,  4.41s/it]
# 12:56:05 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:08 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:56:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:12 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:07,  3.68s/it]12:56:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:16 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.78s/it]12:56:16 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:19 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.76s/it]
# 12:56:20 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:56:24 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:28 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:09,  4.62s/it]12:56:29 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:32 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.05s/it]12:56:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:36 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:12<00:00,  4.13s/it]
# 12:56:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:39 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:56:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:44 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:10,  5.14s/it]12:56:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:49 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:09<00:04,  4.76s/it]12:56:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:52 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:13<00:00,  4.44s/it]
# 12:56:53 - cmdstanpy - INFO - Chain [1] start processing
# 12:56:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:56:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:01 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:10,  5.04s/it]12:57:02 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:04 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.66s/it]12:57:05 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:07 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:10<00:00,  3.59s/it]
# 12:57:08 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:11 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:57:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:16 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:09,  4.77s/it]12:57:16 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:21 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:09<00:05,  5.01s/it]12:57:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:26 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:14<00:00,  4.93s/it]
# 12:57:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:30 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:57:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:33 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.46s/it]12:57:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:37 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.81s/it]12:57:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:40 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:10<00:00,  3.61s/it]
# 12:57:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:46 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:57:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:51 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:09,  4.67s/it]12:57:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:54 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.85s/it]12:57:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:57:57 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:10<00:00,  3.61s/it]
# 12:57:58 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:01 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:58:02 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:05 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:08,  4.17s/it]12:58:06 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:09 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.27s/it]12:58:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:13 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.99s/it]
# 12:58:14 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:17 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:58:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:23 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:11,  5.59s/it]12:58:23 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:27 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:09<00:04,  4.83s/it]12:58:28 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:31 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:13<00:00,  4.55s/it]
# 12:58:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:35 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:58:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:40 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:08,  4.25s/it]12:58:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:43 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.89s/it]12:58:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:47 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.92s/it]
# 12:58:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:58:52 - cmdstanpy - INFO - Chain [1] start processing
# 12:58:55 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:08,  4.10s/it]12:58:56 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:01 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:09<00:04,  4.73s/it]12:59:01 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:05 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:13<00:00,  4.60s/it]
# 12:59:06 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:09 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:59:10 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:12 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.43s/it]12:59:13 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:17 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:04,  4.03s/it]12:59:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:21 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:12<00:00,  4.06s/it]
# 12:59:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:27 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:59:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:30 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:06,  3.42s/it]12:59:31 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:34 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:06<00:03,  3.43s/it]12:59:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:37 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:10<00:00,  3.37s/it]
# 12:59:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:41 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:59:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:46 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:09,  4.97s/it]12:59:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:50 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.21s/it]12:59:50 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:53 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:12<00:00,  4.07s/it]
# 12:59:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:59:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]12:59:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:02 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:10,  5.15s/it]13:00:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:06 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:09<00:04,  4.45s/it]13:00:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:09 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:12<00:00,  4.22s/it]
# 13:00:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:00:15 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:18 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:08,  4.08s/it]13:00:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:21 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.53s/it]13:00:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:25 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.76s/it]
# 13:00:26 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:28 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:00:29 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:33 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:09,  4.89s/it]13:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:39 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:10<00:05,  5.30s/it]13:00:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:16<00:00,  5.37s/it]
# 13:00:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:48 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:00:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:52 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:03<00:07,  3.90s/it]13:00:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:56 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:07<00:03,  3.86s/it]13:00:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:00 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  3.84s/it]
# 13:01:00 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:06 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:01:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:10 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:08,  4.11s/it]13:01:11 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:15 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.44s/it]13:01:15 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:19 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:13<00:00,  4.42s/it]
# 13:01:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:01:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:27 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:09,  4.70s/it]13:01:28 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:31 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.29s/it]13:01:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:35 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:11<00:00,  4.00s/it]
# 13:01:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:38 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:01:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:43 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:11,  5.62s/it]13:01:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:48 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:10<00:04,  4.90s/it]13:01:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:52 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:14<00:00,  4.88s/it]
# 13:01:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:01:58 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:01:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:02:03 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:05<00:10,  5.37s/it]13:02:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:02:07 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:08<00:04,  4.25s/it]13:02:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:02:11 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:12<00:00,  4.22s/it]
# 13:02:11 - cmdstanpy - INFO - Chain [1] start processing
# 13:02:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/3 [00:00<?, ?it/s]13:02:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:02:21 - cmdstanpy - INFO - Chain [1] done processing
#  33%|███▎      | 1/3 [00:04<00:09,  4.84s/it]13:02:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:02:27 - cmdstanpy - INFO - Chain [1] done processing
#  67%|██████▋   | 2/3 [00:10<00:05,  5.26s/it]13:02:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:02:32 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 3/3 [00:15<00:00,  5.07s/it]
#      changepoint_prior_scale  seasonality_prior_scale  changepoint_range  \
# 144                      0.5                     0.01                0.8
# 150                      0.5                     0.05                0.8
# 162                      0.5                     0.50                0.8
# 156                      0.5                     0.10                0.8
# 168                      0.5                     1.00                0.8
# ..                       ...                      ...                ...
# 165                      0.5                     0.50                0.9
# 135                      0.2                     1.00                0.9
# 141                      0.2                     5.00                0.9
# 171                      0.5                     1.00                0.9
# 177                      0.5                     5.00                0.9
#
#     seasonality_mode      rmse
# 144         additive  2.776688
# 150         additive  2.790401
# 162         additive  2.792585
# 156         additive  2.797625
# 168         additive  2.801658
# ..               ...       ...
# 165   multiplicative  7.241477
# 135   multiplicative  7.331239
# 141   multiplicative  7.387254
# 171   multiplicative  7.391932
# 177   multiplicative  8.297556
#
# [180 rows x 5 columns]

# %% [markdown]
# **Important** Code above took 41 minutes to run

# %%
tuning_results.sort_values('rmse')
# Out:
#      changepoint_prior_scale  seasonality_prior_scale  changepoint_range  \
# 144                      0.5                     0.01                0.8
# 150                      0.5                     0.05                0.8
# 162                      0.5                     0.50                0.8
# 156                      0.5                     0.10                0.8
# 168                      0.5                     1.00                0.8
# ..                       ...                      ...                ...
# 165                      0.5                     0.50                0.9
# 135                      0.2                     1.00                0.9
# 141                      0.2                     5.00                0.9
# 171                      0.5                     1.00                0.9
# 177                      0.5                     5.00                0.9
#
#     seasonality_mode      rmse
# 144         additive  2.776688
# 150         additive  2.790401
# 162         additive  2.792585
# 156         additive  2.797625
# 168         additive  2.801658
# ..               ...       ...
# 165   multiplicative  7.241477
# 135   multiplicative  7.331239
# 141   multiplicative  7.387254
# 171   multiplicative  7.391932
# 177   multiplicative  8.297556
#
# [180 rows x 5 columns]

# %% [markdown]
# From the code above we see the best params are:
# - changepoint_prior_scale = 0.5 (Prophet's default is 0.05)
# - seasonality_prior_scale  = 0.01  (Prophet's default is 10)
# - changepoint_range = 0.8 (Prophet's default is 0.8)
# - seasonality_mode = additive (Prophet's defeault is additive)
#
# We will now train a model with best params

# %% [markdown]
# #### Training and Forecasting After Hyperparam Tuning

# %%
import itertools
stock_hist_daily2=stock_hist_daily1.reset_index().rename(columns={'Date':'ds',stock:'y'}).copy()
date_train_test = '2024-07-31'
stock_train2=stock_hist_daily2.loc[stock_hist_daily2.ds<=date_train_test].copy()
stock_test2=stock_hist_daily2.loc[stock_hist_daily2.ds>date_train_test].copy()

## COVID
# Python
lockdowns = pd.DataFrame([
    {'holiday': 'lockdown_1', 'ds': '2020-03-21', 'lower_window': 0, 'ds_upper': '2020-06-06'},
    {'holiday': 'lockdown_2', 'ds': '2020-07-09', 'lower_window': 0, 'ds_upper': '2020-10-27'},
    {'holiday': 'lockdown_3', 'ds': '2021-02-13', 'lower_window': 0, 'ds_upper': '2021-02-17'},
    {'holiday': 'lockdown_4', 'ds': '2021-05-28', 'lower_window': 0, 'ds_upper': '2021-06-10'}
])
for t_col in ['ds', 'ds_upper']:
    lockdowns[t_col] = pd.to_datetime(lockdowns[t_col])
lockdowns['upper_window'] = (lockdowns['ds_upper'] - lockdowns['ds']).dt.days


best_results = tuning_results.sort_values('rmse').head(1)

param_grid = {  
    'changepoint_prior_scale': best_results['changepoint_prior_scale'].values,
    'seasonality_prior_scale': best_results['seasonality_prior_scale'].values,
    'changepoint_range': best_results['changepoint_range'].values
    
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

m = Prophet(**all_params[0], holidays=lockdowns, seasonality_mode='additive')    
m.add_regressor('day', mode='additive')
m.add_regressor('day_of_week',mode='additive')
m.add_regressor('day_of_year',mode='additive')
m.add_regressor('week_of_year',mode='additive')
m.add_regressor('month',mode='additive')
m.add_regressor('quarter',mode='additive')
m.add_regressor('year',mode='additive')
m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
m.fit(stock_train2)

forecast = m.predict(stock_test2)
# Out:
# 13:12:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:12:46 - cmdstanpy - INFO - Chain [1] done processing

# %%
# EVALUATE WITH ERROR METRICS 
mse=np.sqrt(mean_squared_error(y_true=stock_test2['y'],y_pred=forecast['yhat']))

mae = mean_absolute_error(y_true=stock_test2['y'],
                   y_pred=forecast['yhat'])

mape = mean_absolute_percentage_error(y_true=stock_test2['y'],
                   y_pred=forecast['yhat'])

print(mse,mae, mape)
# Out:
# 10.139773282309797 9.076596669838576 11.730060009344882

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.scatter(stock_test2.ds, stock_test2['y'], color='r', label= 'Actual Test Values')
fig = m.plot(forecast, ax=ax)
ax.set_xbound(lower=pd.to_datetime('2024-08-01'),
              upper=pd.to_datetime('2024-09-30'))
#ax.set_ylim(70, 90)
plt.xticks(rotation=45)
ax.legend(loc='lower left') 
plot = plt.suptitle('Actual vs Forecasted')
